# %% [markdown]
# ## **Import Libraries**
# ___
#
# Import the libraries we will use to process the dataset as well as visualize insights from the cleaned data.

# %%
# Import Analytical Libraries
import pandas as pd
import numpy as np 

# Import visualization libraries
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import seaborn as sns

# Statistics Libraries
from scipy.stats import kurtosis, skew, shapiro
from sklearn.preprocessing import OrdinalEncoder, RobustScaler
from sklearn.metrics import mutual_info_score, silhouette_score
from sklearn.cluster import KMeans

# Misc Libraries
from typing import Optional

# %% [markdown]
# ## **Read Files**
# ___
#
# Section reads in the files that will be required for anlaysis, and sets the dataframes to return all the features of the dataframe, rather than truncating the columns. We also set the style of the plots we will be visualizing.

# %%
# Read in the HR attrition csv file.
df = pd.read_csv('data/HR-Employee-Attrition.csv')

# Return all columns when displaying dataframe.
pd.set_option('display.max_columns', None)

# Set the style of the plots
plt.style.use('ggplot')
# Set default colormap for continuous data (both Matplotlib and Seaborn)
plt.rcParams['image.cmap'] = 'rocket'
# Set default palette for categorical data
sns.set_palette('rocket')

# %% [markdown]
# ## **Dataset Identification**
# ___
# Identify the shape and size of the dataset along with its axes and datatypes for each feature to understand the overall structure of the dataset that has been read in.

# %%
# Return the shape and size of the dataset
print(f'Shape of the dataset: {df.shape}\nSize of the dataset: {df.size}')
# Out:
# Shape of the dataset: (1470, 35)
# Size of the dataset: 51450

# %%
# Return the axes of the dataset
df.axes
# Out:
# [RangeIndex(start=0, stop=1470, step=1),
#  Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#         'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#         'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#         'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#         'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#         'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#         'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#         'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#         'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#         'YearsWithCurrManager'],
#        dtype='object')]

# %%
# Return the datatypes of each feature in the dataset
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# Reaturn the top 5 rows of the dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# Return the bottom 5 rows of the dataset
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %% [markdown]
# ## **Dataset Preprocessing**
# ___
# Identify the shape and size of the dataset along with its axes and datatypes for each feature to understand the overall structure of the dataset that has been read in.

# %% [markdown]
# ### 1. **Data Cleaning**
# The data cleaning process is an essential step during data preprocessing, as it helps ensure the quality and consistency of the dataset for analysis or model training

# %% [markdown]
# #### 1.1 **Duplicate Values**
# In the context of a dataframe, a record can be a duplicate of another record, if all the data values of each feature are identical. A record can also be considered a duplicate if the data values of a specified subset of features are identical. In this section, we look to identify and remove the duplicate values within the dataset.

# %%
# Return the total number of duplicated values in the dataset
dupes = df.duplicated().sum()
print(f'Total duplicate values within the dataset: {dupes}')
# Out:
# Total duplicate values within the dataset: 0

# %% [markdown]
# #### 1.2 **Null Values**
# Null values are missing data values within a feature of record. These missing values need to be identified and either removed or imputed.

# %%
# Return the total number of null values in the dataset
nulls = np.count_nonzero(df.isnull().values)
print(f'Total null values in the dataset: {nulls}')
# Out:
# Total null values in the dataset: 0

# %% [markdown]
# #### 1.3 **Miscellaneous Data Errors**
# These errors can be generalized as the errors found in the data values of the records in the dataframe. This step includes converting features to correct datatypes. In this section we look to correct those data errors in order to feed a clean dataset to our machine learning models.

# %% [markdown]
# ##### 1.3.1 **Categorical Features**
# In this section, we go through our categorical variables and see the values that are found in the feature. We will then drop features we deem redundant. This is also done to reduce the noise of the dataset as to minimise the chances of overfitting by providing the model with complex data with redundant features to make predictions on.

# %%
# Store a subset of the dataset with only the categorical features
categorical_subset = df.select_dtypes(include='object')
categorical_subset
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
# Return the total number of unique values in the categorical features
categorical_subset.apply(lambda x: x.nunique())
# Out:
# Attrition         2
# BusinessTravel    3
# Department        3
# EducationField    6
# Gender            2
# JobRole           9
# MaritalStatus     3
# Over18            1
# OverTime          2
# dtype: int64

# %%
# Return the unique values in each categorical feature
categorical_subset.apply(lambda x: x.unique())
# Out:
# Attrition                                                 [Yes, No]
# BusinessTravel       [Travel_Rarely, Travel_Frequently, Non-Travel]
# Department         [Sales, Research & Development, Human Resources]
# EducationField    [Life Sciences, Other, Medical, Marketing, Tec...
# Gender                                               [Female, Male]
# JobRole           [Sales Executive, Research Scientist, Laborato...
# MaritalStatus                           [Single, Married, Divorced]
# Over18                                                          [Y]
# OverTime                                                  [Yes, No]
# dtype: object

# %%
# Check the total number of values in the Over18 feature
categorical_subset['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
# Create a copy of the dataframe
df2 = df.copy()

# Drop the faeture Over18 because all the records are individuals that are over the age of 18.
df2.drop(columns=['Over18'], inplace=True)

# %% [markdown]
# ##### 1.3.2 **Numeric Features**
# In this section, we will look at our numeric features and find look at the relationship between some of these features. This is done in order to again select features that can be seen as redundant with regards to the dataset.

# %%
# Store a subset of the dataset with only the numeric features
numeric_subset = df2.select_dtypes(include='number')
numeric_subset
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
# Return the features that would determine monthly income and determine if there is a relationship between 
# the rates and the monthly income
import re
rate_features = [column for column in numeric_subset
                 if re.search('[rR]ate\\b', column) != None] + ['MonthlyIncome']

corr_matrix = df2.loc[:, rate_features].corr()
sns.heatmap(corr_matrix, annot=True, linewidths=0.8)
plt.tight_layout()
plt.show()

# %%
# Drop the DailyRate, HourlyRate and MonthlyRate features because they are in no way related to 
# MonthlyIncome. This would be the assumption as these values would be used to calculate the MonthlyIncome
df2.drop(columns=['DailyRate', 'HourlyRate', 'MonthlyRate'], inplace=True)

# %%
# Return the total number of unique values in each numeric feature
unique_count_numeric = numeric_subset.apply(lambda x: x.nunique())
unique_count_numeric
# Out:
# Age                           43
# DailyRate                    886
# DistanceFromHome              29
# Education                      5
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobSatisfaction                4
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %%
# Return the features with 5 or less unique values
unique_count_numeric[unique_count_numeric <= 5]
# Out:
# Education                   5
# EmployeeCount               1
# EnvironmentSatisfaction     4
# JobInvolvement              4
# JobLevel                    5
# JobSatisfaction             4
# PerformanceRating           2
# RelationshipSatisfaction    4
# StandardHours               1
# StockOptionLevel            4
# WorkLifeBalance             4
# dtype: int64

# %%
# Drop the EmployeeCount and StandardHours features as there is only one single value within each feature
df2.drop(columns=['EmployeeCount', 'StandardHours'], inplace=True)

# %%
# Return the features with completely unique values for each record
unique_count_numeric[unique_count_numeric == df2.shape[0]]
# Out:
# EmployeeNumber    1470
# dtype: int64

# %%
# Drop the EmployeeNumber feature as this is an identification feature and would not bring any significant 
# insights into our analysis
df2.drop(columns=['EmployeeNumber'], inplace=True)

# %% [markdown]
# #### 1.4 **Outlier Values**
# An outlier is a data point that differs significantly from other observations in a dataset. Outliers can occur due to variability in the data or errors in measurement, and they can influence the results of statistical analyses and machine learning models. In this section, we look to identify all the outlier values inn each feature of the dataset.

# %%
def outlierIQR(column: str, dataframe: Optional[pd.DataFrame]=df, return_outliers: Optional[bool]=False) -> None:
    """
    A function that outputs features from the pandas.dataframe object passed in the dataframe 
    parameter that have outlier values, and the total number of outlier values in the feature. 
    The outliers are found using the IQR method. 

    Args:
        column: string.
            - Name of the column that can be found   within the pandas.dataframe object passed in the dataframe
            parameter.
        dataframe: pandas.dataframe.
            - A pandas dataframe.

    Returns:
        None
    """
    # Store the quantile values 
    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)

    # Return the interquartile range
    IQR = q3 - q1

    # Create the upper and lower limits 
    upper_limit = dataframe[column] > q3 + (IQR * 1.5)
    lower_limit = dataframe[column] < q1 - (IQR * 1.5)

    # Return the outliers of the feature
    outliers = dataframe[column][upper_limit | lower_limit]

    if len(outliers) > 0:
        print(f'{column}\nTotal Outliers: {len(outliers)}\n')
        if return_outliers ==True:
            return outliers.index.to_list()


for feature in numeric_subset:
    outlierIQR(feature)
# Out:
# MonthlyIncome
# Total Outliers: 114
#
# NumCompaniesWorked
# Total Outliers: 52
#
# PerformanceRating
# Total Outliers: 226
#
# StockOptionLevel
# Total Outliers: 85
#
# TotalWorkingYears
# Total Outliers: 63
#
# TrainingTimesLastYear
# Total Outliers: 238
#
# YearsAtCompany
# Total Outliers: 104
#
# YearsInCurrentRole
# Total Outliers: 21
#
# YearsSinceLastPromotion
# Total Outliers: 107
#
# YearsWithCurrManager
# Total Outliers: 14

# %% [markdown]
# #### 1.5 **Feature Engineering**
# Feature engineering involves a process whereas we combine features that in isolation do not have a strong relationship with the dependent variable, but when combined are correlated to the dependant variable.

# %% [markdown]
# ##### 1.5.1 **Bin Age Feature**
# This section involves creating a binned feature to capture age brackets, from the Age feature.

# %%
# Create a copy of the dataframe 
df3 = df2.copy()

# %%
# Store the desired labels for the binning of the Age feature.
age_labels = ['Youth', 'Young Adult', 'Middle Age', 'Old Age']
# Store the bin values 
age_bins = [0, 19, 39, 59, np.inf]

# Bin the values and store as a variable
age_feature_binning = pd.cut(df2['Age'], bins=age_bins, labels=age_labels)

# Insert the values on the right of the Age feature.
df2.insert(df2.columns.get_loc('Attrition'), 'AgeBin', age_feature_binning)

# %% [markdown]
# ##### 1.5.2 **Bin MonthlyIncome Feature**
# This section involves creating a binned feature to capture monthly income brackets, from the MonthlyIncome feature.

# %%
# Create a copy of the dataframe
df3 = df2.copy()

# %%
# Visualize boxplot of the feature
sns.boxplot(df3['MonthlyIncome'], orient='h')
plt.tight_layout()
plt.show()

# %%
# Use quantile values to determine values to bin with 
q1 = df3['MonthlyIncome'].quantile(0.25)
q2 = df3['MonthlyIncome'].quantile(0.5)
q3 = df3['MonthlyIncome'].quantile(0.75)
iqr = q3 - q1 
whisker = q3 + (iqr * 1.5)

# Store the labels for the binning of the MonthlyIncome feature
income_labels = ['Low', 'Average', 'Medium', 'High']
# Store bin values
income_bins = [0, q1, q3, whisker, np.inf]

# Bin the values and store as a variable
income_feature_bin = pd.cut(df3['MonthlyIncome'], bins=income_bins, labels=income_labels)
# Insert the column to the lefft of the MonthlyRate feature.
df3.insert(df3.columns.get_loc('NumCompaniesWorked'), 'IncomeBin', income_feature_bin)

# %% [markdown]
# ##### 1.5.3 **Label Encoding**
#
# In this section, we look to cast categorical features into numeric features. This is done because the dataset that needs to be fed to our model needs to have numeric features (Unless dealing with decision trees, but it is generally good practise to cast categorical features into numeric ones). This process can either be done through one-hot encoding, or label encoding. Label encoding is used when there is a logical hierachial order to the unique values in the feature. For example, low<medium<high.

# %%
# Create a copy of the dataframe
df4 = df3.copy()

# %%
def labelEncoding(dataframe:pd.DataFrame, column:str, value_order: list) -> pd.Series:
    """
    Performs ordinal encoding on a specified column of a DataFrame based on a given order of values.

    Args:
        dataframe :
            - The input DataFrame containing the column to be encoded.
        column :
            - The name of the column to be encoded.
        value_order :
            - A list of categories in the desired ordinal order. The list should contain all possible unique values
            from the column, arranged in increasing order of rank (i.e., from lowest to highest).

    Returns:
    pd.Series
        The encoded column, where each category has been replaced by an integer according to its ordinal position
        in the `value_order` list. The transformation is done in-place on the original DataFrame column.
    
    """
    # Instantiate the label encoder
    encoder = OrdinalEncoder(categories=[value_order], dtype=int)

    # Fit and Transform the column
    dataframe[column] = encoder.fit_transform(dataframe[[column]])

    return dataframe[column]


df4['BusinessTravel'] = labelEncoding(
    df4, 'BusinessTravel', ['Non-Travel', 'Travel_Rarely', 'Travel_Frequently']
)
df4['IncomeBin'] = labelEncoding(
    df4, 'IncomeBin', ['Low', 'Average', 'Medium', 'High']
)
df4['AgeBin'] = labelEncoding(
    df4, 'AgeBin', ['Youth', 'Young Adult', 'Middle Age', 'Old Age']
)

# %% [markdown]
# ##### 1.5.4 **One-Hot Encoding**
#
# One-hot encoding involves creating new features from the unique values of the feature, and making the values binary where if the record has that partiicular value for that feature, a 1 is returned, and 0 if not.

# %%
df4.select_dtypes(exclude='number').columns
# Out:
# Index(['Attrition', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus', 'OverTime'],
#       dtype='object')

# %%
# Create a copy of the dataframe
df5 = df4.copy()

# Store the categorical feaures
categorical_features = df4.select_dtypes(exclude='number').columns

# Store as encoded dataframe
encoded_df = pd.get_dummies(df5, columns=categorical_features, drop_first=True,dtype=int)
encoded_df
# Out:
#       Age  AgeBin  BusinessTravel  DistanceFromHome  Education  \
# 0      41       2               1                 1          2
# 1      49       2               2                 8          1
# 2      37       1               1                 2          2
# 3      33       1               2                 3          4
# 4      27       1               1                 2          1
# ...   ...     ...             ...               ...        ...
# 1465   36       1               2                23          2
# 1466   39       1               1                 6          1
# 1467   27       1               1                 4          3
# 1468   49       2               2                 2          3
# 1469   34       1               1                 8          3
#
#       EnvironmentSatisfaction  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                           2               3         2                4
# ...

# %% [markdown]
# ## **Feature Importance**
# ___
# Looks at the feature importance with regards to the dependent variable. A mutual info score is given to the feature based on the change that occurs within the independent variable and the affect it has on the dependent variable.

# %%
# Split the datasets into dependent and independent variables
X = encoded_df.drop(columns=['Attrition_Yes'])
y = encoded_df['Attrition_Yes']

# %%
# Use the Mutual Info Score library to return the top ten most important features to determine attrition
mi_score = {column: mutual_info_score(X[column], y) for column in X}
mi_score_df = pd.DataFrame(mi_score, index=['MI Score']).T.sort_values(by='MI Score', ascending=False)
mi_score_df
# Out:
#                                        MI Score
# MonthlyIncome                      4.029046e-01
# Age                                3.911303e-02
# TotalWorkingYears                  3.754542e-02
# YearsAtCompany                     3.098803e-02
# OverTime_Yes                       2.768761e-02
# YearsWithCurrManager               2.522910e-02
# JobLevel                           2.498002e-02
# YearsInCurrentRole                 2.359109e-02
# IncomeBin                          2.220189e-02
# StockOptionLevel                   2.098402e-02
# MaritalStatus_Single               1.454274e-02
# DistanceFromHome                   1.121735e-02
# AgeBin                             1.077430e-02
# JobRole_Sales Representative       9.719548e-03
# YearsSinceLastPromotion            9.606046e-03
# NumCompaniesWorked                 8.765037e-03
# JobInvolvement                     8.732048e-03
# BusinessTravel                     8.081713e-03
# EnvironmentSatisfaction            6.998418e-03
# ...

# %% [markdown]
# ## **Clustering**
# ___
# Clustering is an unsupervised learning technique used in machine learning and data analysis to group data points into clusters based on their behavioural similarities. In this section, we will look to cluster the employees using the top 4 most important features in determining the Attrition of an employee. This includes, MonthlyIncome, Age, TotalWorkingYears, and YearsAtCompany.

# %%
# Store the features we will be clustering with 
cluster_features = X.loc[:, ['MonthlyIncome', 'Age', 'TotalWorkingYears', 'YearsAtCompany']]

cluster_features
# Out:
#       MonthlyIncome  Age  TotalWorkingYears  YearsAtCompany
# 0              5993   41                  8               6
# 1              5130   49                 10              10
# 2              2090   37                  7               0
# 3              2909   33                  8               8
# 4              3468   27                  6               2
# ...             ...  ...                ...             ...
# 1465           2571   36                 17               5
# 1466           9991   39                  9               7
# 1467           6142   27                  6               6
# 1468           5390   49                 17               9
# 1469           4404   34                  6               4
#
# [1470 rows x 4 columns]

# %%
outliers = []
for feature in cluster_features:
    feature_outlier = outlierIQR(feature, return_outliers=True)
    if isinstance(feature_outlier, type(None)):
        continue
    outliers.append(feature_outlier)

# Flatten the nested list
outliers = [element for sublist in outliers for element in sublist]

# Convert the outliers to a set to remove the duplicated index values, and convert to a list again
outliers = list(set(outliers))
# Out:
# MonthlyIncome
# Total Outliers: 114
#
# TotalWorkingYears
# Total Outliers: 63
#
# YearsAtCompany
# Total Outliers: 104

# %%
# Store the outlier dataframe
outlier_df = cluster_features.loc[outliers, :]
outlier_df
# Out:
#       MonthlyIncome  Age  TotalWorkingYears  YearsAtCompany
# 1024          17169   47                 26              20
# 523            3221   50                 20              20
# 526            4553   39                 20              20
# 18            15427   53                 31              25
# 1043          16598   53                 35               9
# ...             ...  ...                ...             ...
# 489           16627   43                 21               1
# 1008          17328   54                 29              20
# 497           19513   44                 26               2
# 1009          19701   58                 32               9
# 1010          14732   55                 31               7
#
# [185 rows x 4 columns]

# %%
# Store the non-outlier dataframe
non_outlier_df = cluster_features[~cluster_features.index.isin(outliers)]
non_outlier_df
# Out:
#       MonthlyIncome  Age  TotalWorkingYears  YearsAtCompany
# 0              5993   41                  8               6
# 1              5130   49                 10              10
# 2              2090   37                  7               0
# 3              2909   33                  8               8
# 4              3468   27                  6               2
# ...             ...  ...                ...             ...
# 1465           2571   36                 17               5
# 1466           9991   39                  9               7
# 1467           6142   27                  6               6
# 1468           5390   49                 17               9
# 1469           4404   34                  6               4
#
# [1285 rows x 4 columns]

# %%
def statistics(dataframe: pd.DataFrame) -> None:
    """
    A function that outputs statistics for features with more than 12 unique values.
    The skew and Kurtosis values, along with the p-value from the Shapiro-Wilk test. These values help
    evaluate the distribution of the features of the dataframe passed in to the dataframe parameter. 

    Args: 
        dataframe:
            - A pandas dataframe object.

    Returns: 
        None
    """
    for column in dataframe:
        if dataframe[column].nunique() > 5:
            _skew = skew(dataframe[column])
            _kurtosis = kurtosis(dataframe[column], fisher=True)
            print(
                f"\n{column}\n"
                f"skew: {_skew:.4f}\n"
                f"kurtosis: {_kurtosis:.4f}"
            )

            # Perform Shapiro-Wilk test
            stat, p_value = shapiro(dataframe[column])

            # Print the results
            print(f"KS Normality test: {stat:.4f}")
            print(f"P-value: {p_value:.4f}")

            # Interpret the p-value
            alpha = 0.05
            if p_value > alpha:
                print("The data is likely normally distributed (fail to reject H0).")
            else:
                print("The data is not normally distributed (reject H0).")

            # Check the absolute values of each skew value of a feature
            if np.abs(_skew) < 0.5:
                print('distribution is almost symmetrical')
            elif 0.5 <= np.abs(_skew) <= 1:
                print('distribution is modertely skewed')
            else:
                print('distribution is highly skewed')
            
            # Extremity of tail distribution
            if _kurtosis > 0:
                print(
                    f'Leptokurtic distribution - heavier tails and a sharper peak than the '
                    f'normal distribution.\n'
                    f'This type of distribution is often associated with higher peakedness '
                    f'and a greater probability of extreme values.\n'
                )
            elif _kurtosis < 0:
                print(
                    f'Platykurtic distribution - lighter tails and a flatter peak than the '
                    f'normal distribution.\n'
                    f'This type of distribution is often associated with less peakedness ' 
                    f'and a lower probability of extreme values.\n'
                )
            else:
                print(
                    f'Mesokurtic distribution - similar peak and tail shape as the normal '
                    f'distribution.\n'
                    )
                

statistics(non_outlier_df)
# Out:
# MonthlyIncome
# skew: 1.2383
# kurtosis: 1.2263
# KS Normality test: 0.8868
# P-value: 0.0000
# The data is not normally distributed (reject H0).
# distribution is highly skewed
# Leptokurtic distribution - heavier tails and a sharper peak than the normal distribution.
# This type of distribution is often associated with higher peakedness and a greater probability of extreme values.
#
#
# Age
# skew: 0.5816
# kurtosis: 0.1020
# KS Normality test: 0.9723
# P-value: 0.0000
# The data is not normally distributed (reject H0).
# distribution is modertely skewed
# Leptokurtic distribution - heavier tails and a sharper peak than the normal distribution.
# This type of distribution is often associated with higher peakedness and a greater probability of extreme values.
#
#
# TotalWorkingYears
# skew: 0.7434
# kurtosis: 0.5442
# KS Normality test: 0.9553
# P-value: 0.0000
# The data is not normally distributed (reject H0).
# distribution is modertely skewed
# ...

# %%
# Visualize the distribution of the features before scaling and transformations
plt.figure(figsize=(18, 8))

for i, feature in enumerate(non_outlier_df):
    plt.subplot(2, 2, 1 + i)
    sns.kdeplot(non_outlier_df[feature], fill=True)
    plt.suptitle('Feature Distribution', fontsize=16, weight='bold')

plt.tight_layout()
plt.show()

# %%
def featureScaling(dataframe: pd.DataFrame, column: str, transform_features: list) -> dict[str, np.ndarray]:
    """
    Applies different scaling or transformation techniques to a feature based on its characteristics.

    Args:
        - dataframe (pd.DataFrame): The DataFrame containing the features.
        - column (str): The name of the feature/column to scale or transform.
        - transform_features (list): List of feature names that need a log transformation 
        followed by robust scaling.

    Returns:
        - dict: A dictionary with the column name as the key and the scaled or transformed 
        feature values as the value.

    Raises:
    ValueError: If an incorrect column name is provided.
    """
    if column in transform_features:
        # Apply Log transformation
        transform = np.log1p(dataframe[[column]])

        # Instantiate the RobustScaler
        r_scaler = RobustScaler()
        # Fit and transform the feature
        transform_scale = r_scaler.fit_transform(transform)

        # Store as a dictionary
        transform_data = {column: transform_scale.flatten()}
        print(f'{column} has been transformed and scaled')

        return transform_data
    
    else:
        # Instantiate the RobustScaler
        r_scaler = RobustScaler()

        # Fit the model with the feature
        transform_scale = r_scaler.fit_transform(dataframe[[column]])

        # Store as a dictionary
        transform_data = {column: transform_scale.flatten()}
        print(f'{column} Has been scaled')

        return transform_data

# %%
transform_scale_features = ['MonthlyIncome']

table_data = {}
for column in non_outlier_df:
    data = featureScaling(non_outlier_df, column, transform_scale_features)
    table_data.update(data)

scaled_df = pd.DataFrame(table_data)
# Out:
# MonthlyIncome has been transformed and scaled
# Age Has been scaled
# TotalWorkingYears Has been scaled
# YearsAtCompany Has been scaled

# %%
# Visualize the distribution of the scaled and transformed features 
plt.figure(figsize=(18, 8))

for i, feature in enumerate(scaled_df):
    plt.subplot(2, 2, 1 + i)
    sns.kdeplot(scaled_df[feature], fill=True)
    plt.suptitle('Feature Distribution', fontsize=16, weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1. **Selecting K-Clusters**
# In this section we look for the optimal number of clusters for the dataset.

# %%
# Instantiate the kmeans clustering model 
def kmeansInertias(k: int, r: int, X: pd.DataFrame) -> float:
    """
    Computes the inertia (sum of squared distances of samples to their closest cluster center)
    for a KMeans clustering model with a specified number of clusters and random state.

    Args:
        k (int): 
            The number of clusters for the KMeans model.
        r (int): 
            The random state to ensure reproducibility.
        X (pd.DataFrame): 
            The dataset on which to perform clustering.

    Returns:
        float:
            The inertia of the fitted KMeans model, representing the clustering quality.
    """
    kmeans = KMeans(n_clusters=k, random_state=r)
    kmeans.fit(X)

    return kmeans.inertia_


def elbow_Kmeans(X: pd.DataFrame, dataset: str, max_k=10, r=42) -> None:
    """
    Generates an elbow graph to help determine the optimal number of clusters (K) 
    for KMeans clustering on a given dataset by plotting the inertia values 
    for each K in the specified range.

    Args:
        X (pd.DataFrame):
            The dataset on which to perform KMeans clustering.
        dataset (str):
            The name of the dataset, used for the plot title.
        max_k (int, optional):
            The maximum number of clusters to consider for the elbow method. Default is 10.
        r (int, optional):
            The random state to ensure reproducibility across clustering runs. Default is 42.

    Returns:
        None: 
            Displays an elbow graph to visually determine the optimal K.
    """
    inertias = [kmeansInertias(i, r=r, X=X) for i in range(1, max_k + 1)]
    sns.lineplot(x=range(1, 11), y=inertias, marker='o')
    plt.xlabel('K: Number of clusters')
    plt.ylabel('Inertia')
    plt.title(f'{dataset} Elbow Graph')
    plt.grid(True)

# %%
def silhouetteScore(dataframe: pd.DataFrame, dataset: str) -> None:
    """
    Calculates and plots the silhouette score for KMeans clustering across a range of cluster counts 
    to help assess cluster quality and identify the optimal number of clusters for a dataset.

    Args:
        dataframe (pd.DataFrame): 
            The dataset on which to perform KMeans clustering.
        dataset (str): 
            The name of the dataset, used in the plot title.

    Returns:
        None: 
            Displays a line plot of silhouette scores for different numbers of clusters (K).
    """

    # Silhouette score method
    kmax = 10
    sil = []
    plt.plot()
    for k in range(2, kmax+2):
        kmeans = KMeans(n_clusters=k, random_state=42, max_iter=1000)
        kmeans.fit(dataframe)
        labels = kmeans.labels_
        sil.append(silhouette_score(dataframe, labels, metric='euclidean'))

    sns.lineplot(x=range(2, kmax+2), y=sil, marker='o')
    plt.title(f'Silhouette Score for {dataset}')
    plt.xlabel('K: Number of clusters')
    plt.ylabel(f"Silhouette Score")
    plt.grid(True)


plt.figure(figsize=(12, 10))

plt.subplot(2, 1, 1)
silhouetteScore(scaled_df, dataset='MonthlyIncome, Age, TotalWorkingYears, YearsAtCompany')
plt.subplot(2, 1, 2)
elbow_Kmeans(scaled_df, dataset='MonthlyIncome, Age, TotalWorkingYears, YearsAtCompany')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. **Cluster Predictions**
#
# This process involves predicting the clusters using the selected number of clusters from the previous phase.

# %%
# Predict clusters for non-outlier dataset
k = 2
kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
cluster_labels_ = kmeans.fit_predict(scaled_df)

# Insert predictions into the scaled dataframe
non_outlier_df['Cluster'] = cluster_labels_

non_outlier_df.head()
# Out:
# C:\Users\Lenovo S145\AppData\Local\Temp\ipykernel_24356\1167165333.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_outlier_df['Cluster'] = cluster_labels_
#    MonthlyIncome  Age  TotalWorkingYears  YearsAtCompany  Cluster
# 0           5993   41                  8               6        1
# 1           5130   49                 10              10        1
# 2           2090   37                  7               0        0
# 3           2909   33                  8               8        0
# 4           3468   27                  6               2        0

# %%
# Return the outliers of each feature and store as a seperate dataframe
feature_outliers_ = {}
for feature in cluster_features:
    feature_outlier = outlierIQR(feature, return_outliers=True)
    if isinstance(feature_outlier, type(None)):
        continue
    dct = {f'{feature}_outliers': feature_outlier}
    feature_outliers_.update(dct)
# Out:
# MonthlyIncome
# Total Outliers: 114
#
# TotalWorkingYears
# Total Outliers: 63
#
# YearsAtCompany
# Total Outliers: 104

# %%
# Creating three DataFrames
monthly_income_outliers_df = cluster_features.loc[feature_outliers_.get('MonthlyIncome_outliers'), :]
total_working_years_outliers_df = cluster_features.loc[feature_outliers_.get('TotalWorkingYears_outliers'), :]
years_at_company_outliers_df = cluster_features.loc[feature_outliers_.get('YearsAtCompany_outliers'), :]

# Extracting the index sets from the DataFrames
set1 = set(monthly_income_outliers_df.index)
set2 = set(total_working_years_outliers_df.index)
set3 = set(years_at_company_outliers_df.index)

# Create a Venn diagram using the index sets
plt.figure(figsize=(8, 8))
venn = venn3([set1, set2, set3], ('MonthlyIncome Outliers', 'Total Working Years Outliers', 'Years At Company'))

# Display the Venn diagram
plt.title("Venn Diagram of Index Overlap")
plt.show()

# %%
all_int_indexes = (set1.intersection(set2)).intersection(set3)
monthly_income_AND_years_at_company_indexes = (set1.intersection(set3)).difference(all_int_indexes)
monthly_income_AND_total_working_years_indexes = (set1.intersection(set2)).difference(all_int_indexes)
total_working_years_AND_years_at_company_indexes = (set2.intersection(set3)).difference(all_int_indexes)
years_at_company_ONLY_index = (set3.difference(set2)).difference(set1)
monthly_income_ONLY_index = (set1.difference(set2)).difference(set3)
total_working_years_ONLY_index = (set2.difference(set1)).difference(set3)

# Confirm that the total indexes per variable match the Venn Diagram totals
print(
    f'Intersect group: {len(all_int_indexes)}\n'
    f'Monthly Income and Years at Company group: {len(monthly_income_AND_years_at_company_indexes)}\n'
    f'Monthly Income and Total Working Years group: {len(monthly_income_AND_total_working_years_indexes)}\n'
    f'Total Working Years and Years at Company group: {len(total_working_years_AND_years_at_company_indexes)}\n'
    f'Years at Company group: {len(years_at_company_ONLY_index)}\n'
    f'Monthly Income group: {len(monthly_income_ONLY_index)}\n'
    f'Total Working Years group: {len(total_working_years_ONLY_index)}\n'
)

# Set Cluster column for outlier df as None
outlier_df['Cluster'] = None

# Manually add the cluster names from the outliers
outlier_df.loc[list(all_int_indexes), 'Cluster'] = 2
outlier_df.loc[list(monthly_income_AND_years_at_company_indexes), 'Cluster'] = 3
outlier_df.loc[list(monthly_income_AND_total_working_years_indexes), 'Cluster'] = 4
outlier_df.loc[list(total_working_years_AND_years_at_company_indexes), 'Cluster'] = 5
outlier_df.loc[list(years_at_company_ONLY_index), 'Cluster'] = 6
outlier_df.loc[list(monthly_income_ONLY_index), 'Cluster'] = 7
outlier_df.loc[list(total_working_years_ONLY_index), 'Cluster'] = 8
# Out:
# Intersect group: 16
# Monthly Income and Years at Company group: 36
# Monthly Income and Total Working Years group: 17
# Total Working Years and Years at Company group: 11
# Years at Company group: 41
# Monthly Income group: 45
# Total Working Years group: 19

# %%
# Concatenate the outlier and non outlier dataframes and store the cluster column only as the dataframe
cluster_df =  pd.concat([non_outlier_df, outlier_df], axis=0).loc[:, ['Cluster']]

# Concatenate the cluster dataframe to the df3 dataframe. This will be the dataframe we use to make our analysis
analysis_df = df3.copy()
analysis_df = pd.concat([analysis_df, cluster_df], axis=1)

analysis_df
# Out:
#       Age       AgeBin Attrition     BusinessTravel              Department  \
# 0      41   Middle Age       Yes      Travel_Rarely                   Sales
# 1      49   Middle Age        No  Travel_Frequently  Research & Development
# 2      37  Young Adult       Yes      Travel_Rarely  Research & Development
# 3      33  Young Adult        No  Travel_Frequently  Research & Development
# 4      27  Young Adult        No      Travel_Rarely  Research & Development
# ...   ...          ...       ...                ...                     ...
# 1465   36  Young Adult        No  Travel_Frequently  Research & Development
# 1466   39  Young Adult        No      Travel_Rarely  Research & Development
# 1467   27  Young Adult        No      Travel_Rarely  Research & Development
# 1468   49   Middle Age        No  Travel_Frequently                   Sales
# 1469   34  Young Adult        No      Travel_Rarely  Research & Development
#
# ...

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**
# ___

# %%
# Check the data type of each feature
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   AgeBin                    1470 non-null   category
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  JobInvolvement            1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobRole                   1470 non-null   object
# ...

# %%
# Create a subset of the analysis dataframe to analyse the clusters
analysis_subset = analysis_df.loc[:, ['Cluster', 'MonthlyIncome', 'YearsAtCompany', 'TotalWorkingYears']]

#  Filter to only the non outlier clusters 
non_outlier_analysis = analysis_subset[analysis_subset['Cluster'] <= 1]
non_outlier_analysis
# Out:
#      Cluster  MonthlyIncome  YearsAtCompany  TotalWorkingYears
# 0          1           5993               6                  8
# 1          1           5130              10                 10
# 2          0           2090               0                  7
# 3          0           2909               8                  8
# 4          0           3468               2                  6
# ...      ...            ...             ...                ...
# 1465       1           2571               5                 17
# 1466       1           9991               7                  9
# 1467       0           6142               6                  6
# 1468       1           5390               9                 17
# 1469       0           4404               4                  6
#
# [1285 rows x 4 columns]

# %%
#  Filter to only the outlier clusters 
outlier_analysis = analysis_subset[analysis_subset['Cluster'] > 1]
outlier_analysis
# Out:
#      Cluster  MonthlyIncome  YearsAtCompany  TotalWorkingYears
# 18         5          15427              25                 31
# 25         7          19094              14                 26
# 28         6          10248              22                 24
# 29         7          18947               2                 22
# 45         3          19545              22                 23
# ...      ...            ...             ...                ...
# 1404       6           4332              20                 20
# 1437       7          19431               6                 21
# 1443       3          18880              22                 24
# 1445       6          13570              20                 21
# 1462       6          12031              20                 21
#
# [185 rows x 4 columns]

# %% [markdown]
# #### 1.1 **Cluster Analysis**
#
# During this section, we will look to classify the clusters based on their characteristics, and then rename the clusters to aptly cover characteristics of the values from the features used to characterise the clusters.

# %%
def violinPlot(dataframe: pd.DataFrame):
    plt.figure(figsize=(24, 16))

    for i, column in enumerate(dataframe.drop(columns=['Cluster'])):
        plt.subplot(3, 4, 1 + i)
        sns.violinplot(x=dataframe['Cluster'], y=dataframe[column], hue=dataframe['Cluster'], legend=False)
        sns.violinplot(y=dataframe[column], palette='gray', linewidth=1.0)
        plt.title(f'{column} Value by Cluster')
        plt.ylabel(f'{column} Value')

    plt.suptitle('Cluster Analysis')
    plt.tight_layout()
    plt.show()

# %%
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)
violinPlot(non_outlier_analysis)

# %% [markdown]
# `NON-OUTLIER CLUSTER CLASSIFICATION`:
#
# **Cluster 0**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~2500, to ~4500, which is below the average of the employees that arent outlier earniers, which is ~5000.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~2.5 to 5 years at the company. On average, for employees that arent outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, employees worked ~ 5 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~3 - ~7 years. On average, for employees that arent outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, employees have been working on average, ~10 years
#
# - *Cluster Classification*
#     - **Early-career professionals**
#
# **Cluster 1**
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~5000, to ~9500, which is above the average of the employees that arent outlier earniers, which is ~5000.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~5 to ~10 years at the company. On average, for employees that arent outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, employees worked ~ 5 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~10 - ~17 years. On average, for employees that arent outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, employees have been working on average, ~10 years
#
# - *Cluster Classification*
#     - **Mid-career professionals**

# %%
violinPlot(outlier_analysis)

# %% [markdown]
# `CLUSTER CLASSIFICATION`:
#
# **Cluster 2**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~18000, to ~20000, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~28 to ~32 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~32 - ~35 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Senior Executives**
#
# **Cluster 3**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~17500, to ~20000, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~20 to ~22 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~20 - ~25 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Experienced senior professionals**
#
# **Cluster 4**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~17500, to ~20000, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~5 to ~9 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~30 - ~35 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Highly experienced late-career professionals**
#
# **Cluster 5**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~11000, to ~14000, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~25 to ~32 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~32.5 - ~34 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Veteran Professional**
#
# **Cluster 6**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~6000, to ~13000, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~20 to ~22 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~20 - ~24 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Mid-to-senior professionals**
#
# **Cluster 7**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~15000, to ~19500, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~3 to ~9 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~18 - ~27 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Specialized professionals**
#
# **Cluster 8**:
# - *MonthlyIncome*
#     - Majority of the employees in this cluster earn between ~11000, to ~14500, which is above the average of the employees that are outlier earniers, which is ~17500.
#
# - *YearsAtCompany*
#     - Majority of the employees in this cluster have worked between ~5 to ~10 years at the company. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have worked ~20 years at the company
#
# - *TotalWorkinYears*
#     - Majority of the employees in this cluster have worked between ~30 - ~33 years. On average, for employees that are outliers within the MonthlyIncome, YearsAtCompany and TotalWorkingYears, have been working for, ~25 years
#
# - *Cluster Classification*
#     - **Experienced Mid-Salary Professionals**

# %% [markdown]
# #### 1.2 **Bivariate Analysis with Attrition Feature**

# %%
category_one = (
    [column for column in df3.drop(columns=['Attrition']).select_dtypes(include=['object', 'category'])
     if df3[column].nunique() <= 3]
)


category_two = (
    [column for column in df3.drop(columns=['Attrition']).select_dtypes(include=['object', 'category'])
     if df3[column].nunique() > 3]
)

# %%
category_one
# Out:
# ['BusinessTravel', 'Department', 'Gender', 'MaritalStatus', 'OverTime']

# %%
category_two
# Out:
# ['AgeBin', 'EducationField', 'JobRole', 'IncomeBin']

# %%
plt.figure(figsize=(18, 12))
for i, column in enumerate(category_one):
    plt.subplot(2, 3, i + 1)
    ax = sns.countplot(df3, x=column, hue='Attrition', stat='count')
    plt.title(f'Totals For {column} per Attrition')

    # Add values at the top of each bar
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='baseline', fontsize=12, color='black', 
                    xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insights (Bivariate Analysis)**
#
# #### **Total Attrition per BusinessTravel**:
# ___
# 1. *Travel_Rarely*:
#     * There are a total of **1043** employees who travel rarely.
#     * The retention rate -  approximately **1** employee leave the organisation for every **6** who remain.
#
# 2. *Travel_Frequently*:
#     * There are a total of **277** employees who travel frequently
#     * The retention rate - approximately **1** employee leave the organisation for every **3** who remain.
#
# 3. *Non-Travel*:
#     * There are a total of **150** employees who do not travel
#     * The retention rate - approximately **1** employee leave the organisation for every **12** who remain.
#
# This suggests that employees who have to travel frequently for work, are more likely to leave the organisation.
#
# #### **Total Attrition per Department**:
# ___
# 1. *Sales Department*:
#     * There are a total of **446** employees who are in the Sales Department.
#     * The retention rate - approximately **1** employee leaves the organisation for every **4** who remain.
#
# 2. *R&D Department*:
#     * There are a total of **961** employees who are in the Research and Development Department.
#     * The retention rate - approximately **1** employee leaves the organisation for every **6** who remain.
#
# 3. *Human Resources*:
#     * There are a total of **63** employees who are in the Human Resources Department.
#     * The retention rate - approximately **1** employee leaves the organisation for every **4** who remain.
#
# This suggests that employee attrition is not department related.
#
# #### **Total Attrition per Gender**:
# ___
# 1. *Male*:
#     * There are a total of **882** employees who are are male within the organisation.
#     * The retention rate - approximately **1** male employee leaves the organisation for every **5** who remain.
#
# 2. *Female*:
#     * There are a total of **588** employees who are are female within the organisation.
#     * The retention rate - approximately **1** female employee leaves the organisation for every **6** who remain.
#
# This suggests that employee attrition is not gender related
#
# #### **Total Attrition per Marital Status**:
# ___
# 1. *Single*:
#     * There are a total of **470** employees who are Single.
#     * The retention rate - approximately **1** employee leaves the organisation for every **3** who remain.
#
# 2. *Married*:
#     * There are a total of **673** employees who are married.
#     * The retention rate - approximately **1** employee leaves the organisation for every **7** who remain.
#
# 3. *Divorced*:
#     * There are a total of **327** employees who are divorced.
#     * The retention rate - approximately **1** employee leaves the organisation for every **9** who remain.
#
# This suggests that employee attrition is related to whether an employee is single or not. This suggests that single individuals are more prone to leave the organisation compared to those individuals who are married or have been divorced, this can be because of the flexibility of not having a family that depends on the individual.
#
# #### **Total Attrition per Over time worked**:
# ___
# 1. *Yes*:
#     * There are a total of **416** employees who work overtime.
#     * The retention rate - approximately **1** employee leaves the organisation for every **2** who remain.
#
# 2. *No*:
#     * There are a total of **1054** employees who work overtime.
#     * The retention rate - approximately **1** employee leaves the organisation for every **9** who remain.
#
# This suggests that there is a direct correlation between the attrition of employees and employees that work overtime.

# %%
plt.figure(figsize=(18, 12))
for i, column in enumerate(category_two):
    plt.subplot(2, 2, i + 1)
    ax = sns.countplot(df3, x=column, hue='Attrition', stat='count')
    plt.title(f'Totals For {column} per Attrition')

    if column == 'JobRole':
        # Rotate x-axis labels
        plt.xticks(rotation=45)

        # Add values at the top of each bar
        for p in ax.patches:
            ax.annotate(f'{int(p.get_height())}', 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='baseline', fontsize=12, color='black', 
                        xytext=(0, 5), textcoords='offset points')
            
    else:
        # Add values at the top of each bar
        for p in ax.patches:
            ax.annotate(f'{int(p.get_height())}', 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='baseline', fontsize=12, color='black', 
                        xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insights (Bivariate Analysis)**
#
# #### **Total Attrition per AgeBin**:
# ___
# 1. *Youth*:
#     * There are a total of **17** employees who are considered youth.
#     * The retention rate -  There is a **100%** attrition rate for employees in this category.
#
# 2. *Young Adult*:
#     * There are a total of **931** employees who fall under the young adults.
#     * The retention rate - approximately **1** employee leave the organisation for every **4** who remain.
#
# 3. *Middle Age*:
#     * There are a total of **517** employees who do not travel
#     * The retention rate - approximately **1** employee leave the organisation for every **8** who remain.
#
# 4. *Old Age*:
#     * There are a total of **5** employees who do not travel
#     * The retention rate - There is a **0%** attrition rate for employees in this category
#
# This suggests that attrition is related to age, as employees in the young adult category are the more likely to leave an organisation.  For every **1** employee in this category that leaves the organisation, only **4** remain.
#
# #### **Total Attrition per EducationField**:
# ___
# 1. *Life Science*:
#     * There are a total of **606** employees who have educationn in Life Science field.
#     * The retention rate -  approximately **1** employee leave the organsiation for every **6** who remain.
#
# 2. *Other*:
#     * There are a total of **82** employees who have 'other' education field.
#     * The retention rate -  approximately **1** employee leave the organsiation for every **7** who remain.
#
# 3. *Medical*:
#     * There are a total of **464** employees who have education in Medical field.
#     * The retention rate - approximately **1** employee leave the organsiation for every **6** who remain.
#
# 4. *Marketing*:
#     * There are a total of **159** employees who have education in Marketing field.
#     * The retention rate - approximately **1** employee leave the organsiation for every **4** who remain.
#
# 5. *Technical Degree*:
#     * There are a total of **132** employees who have technical degree.
#     * The retention rate - approximately **1** employee leave the organsiation for every **3** who remain.
#
# 6. *Human Resources*:
#     * There are a total of **27** employees who have education in Human Resources field.
#     * The retention rate - approximately **1** employee leave the organsiation for every **3** who remain.
#
#
# #### **Total Attrition per IncomeBin**:
# ___
# 1. *Low*:
#     * There are a total of **369** employees who are considered to be part of the low income bin.
#     * The retention rate - approximately **1** employee leave the organsiation for every **2** who remain
#
# 2. *Average*:
#     * There are a total of **733** employees who are considered to be part of the average income bin.
#     * The retention rate - approximately **1** employee leave the organisation for every **7** who remain.
#
# 3. *Medium*:
#     * There are a total of **254** employees who are considered to be part of the medium income bin.
#     * The retention rate - approximately **1** employee leave the organisation for every **7** who remain.
#
# 4. *High*:
#     * There are a total of **114** employees who are considered to be part of the high income bin.
#     * The retention rate - approximately **1** employee leave the organisation for every **22** who remain
#
# This suggests that attrition is correlated to income brackets, as the seen with the employees in the low income bracket having a retention ration of approximately **2** employee's being retained for every 1 that leaves the organisation.
#
#
# #### **Total Attrition per JobRole**:
# ___
# 1. *Sales Executive*:
#     * There are a total of **326** employees with the role of sales executive.
#     * The retention rate - approximately **1** employee leave the organisation for every **5** who remain.
#
# 2. *Research Scientist*:
#     * There are a total of **292** employees with the role of research scientis.
#     * The retention rate - approximately **1** employee leave the organisation for every **5** who remain.
#
# 3. *Laboratory Technician*:
#     * There are a total of **259** employees with the role of laboratory technician.
#     * The retention rate - approximately **1** employee leave the organisation for every **3** who remain.
#
# 4. *Manufacturing Director*:
#     * There are a total of **145** employees with the role of manufacturing director.
#     * The retention rate - approximately **1** employee leave the organisation for every **14** who remain.
#
# 5. *Healthcare Representative*:
#     * There are a total of **131** employees with the role of healtchare rep.
#     * The retention rate - approximately **1** employee leave the organisation for every **14** who remain.
#
# 6. *Manager*:
#     * There are a total of **102** employees with the role of manager.
#     * The retention rate - approximately **1** employee leave the organisation for every **19** who remain.
#
# 7. *Sales Representative*:
#     * There are a total of **83** employees with the role of sales rep.
#     * The retention rate - approximately **1** employee leave the organisation for every **2** who remain.
#
# 8. *Research Director*:
#     * There are a total of **80** employees with the role of manager.
#     * The retention rate - approximately **1** employee leave the organisation for every **39** who remain.
#
# 9. *Human Resources*:
#     * There are a total of **52** employees with the role of manager.
#     * The retention rate - approximately **1** employee leave the organisation for every **3** who remain.
#
#
# This suggests that attrition is correlated to job role. This can be seen with the retention ratio differences between the roles. further analysis can be done to find out whether these roles differ significantly with regards to income level and whether certain roles require more overtime or not.

# %% [markdown]
# ### 1.3 **Which profession cluster has the lowest retention rate?**

# %%
# Reassign the values in the Cluster feature based on mapping
cluster_mapping = {
    0: 'Early-career professional',
    1: 'Mid-career professional',
    2: 'Senior Executives',
    3: 'Experienced senior professional',
    4: 'Highly experienced late-career professionals', 
    5: 'Veteran Professional', 
    6: 'Mid-to-senior professionals', 
    7: 'Specialized professionals', 
    8: 'Experienced Mid-Salary Professionals'
}
analysis_df['Cluster'] = analysis_df['Cluster'].map(cluster_mapping)

# Store the dataframe we will use to create a dashboard with
analysis_df.to_csv('data/analysis_df.csv', index=False)

# %%
# Create pivot table with the cluster grouping
retention_attrition_pivot = (
    analysis_df.pivot_table(
    values='AgeBin', index='Cluster',
    columns='Attrition', aggfunc='count',
    fill_value=0
    ).sort_values(by='Yes', ascending=False)
)

# Create Retention rate column
retention_attrition_pivot['RetentionToAttritionRate'] = (
    np.where(
        retention_attrition_pivot['Yes'] != 0,
        retention_attrition_pivot['No'] / retention_attrition_pivot['Yes'],
        0
    )
)

retention_attrition_pivot = round(retention_attrition_pivot.sort_values(by='RetentionToAttritionRate', ascending=False), 2)
retention_attrition_pivot
# Out:
# Attrition                                      No  Yes  \
# Cluster
# Specialized professionals                      44    1
# Experienced Mid-Salary Professionals           18    1
# Experienced senior professional                34    2
# Mid-to-senior professionals                    37    4
# Mid-career professional                       582   71
# Senior Executives                              14    2
# Veteran Professional                            9    2
# Early-career professional                     478  154
# Highly experienced late-career professionals   17    0
#
# Attrition                                     RetentionToAttritionRate
# Cluster
# Specialized professionals                                        44.00
# Experienced Mid-Salary Professionals                             18.00
# Experienced senior professional                                  17.00
# Mid-to-senior professionals                                       9.25
# ...

# %%
plt.figure(figsize=(12, 6))

ax = sns.barplot(retention_attrition_pivot.iloc[:8, :], y='Cluster', x='RetentionToAttritionRate')
ax.bar_label(ax.containers[0])
plt.title('Retention-To-Attrition Rate for Employee Clusters')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.4 **What is the average Age of Early-career professionals?**

# %%
age_cluster_pivot = (
    analysis_df.groupby(['Cluster', 'Gender'], as_index=False)[['Age']].mean().sort_values(by='Age', ascending=False)
)
age_cluster_pivot
# Out:
#                                          Cluster  Gender        Age
# 6   Highly experienced late-career professionals  Female  54.875000
# 3           Experienced Mid-Salary Professionals    Male  54.857143
# 12                             Senior Executives  Female  54.000000
# 17                          Veteran Professional    Male  53.333333
# 7   Highly experienced late-career professionals    Male  53.111111
# 2           Experienced Mid-Salary Professionals  Female  53.083333
# 16                          Veteran Professional  Female  52.800000
# 13                             Senior Executives    Male  52.250000
# 14                     Specialized professionals  Female  48.235294
# 15                     Specialized professionals    Male  45.464286
# 4                Experienced senior professional  Female  44.285714
# 11                   Mid-to-senior professionals    Male  43.900000
# 10                   Mid-to-senior professionals  Female  42.619048
# ...

# %%
plt.figure(figsize=(12, 6))

ax = sns.barplot(age_cluster_pivot, y='Cluster', x='Age', hue='Gender', errorbar=None)

# Add values at the end of each bar (right side of each bar for vertical orientation)
for p in ax.patches:
    ax.annotate(f'{float(p.get_width()):.2f}', 
                (p.get_width()+1, p.get_y() + p.get_height() / 2.), 
                ha='center', va='center', fontsize=8, color='black', 
                xytext=(5, 0), textcoords='offset points')

ax.legend(loc='best')
plt.title('Average Age by Gender per Employee Clustering')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.5 **What is the Average monthly income of Early-career professionals compared to the organisation average?**

# %%
cluster_income_pivot = analysis_df.groupby('Cluster')[['MonthlyIncome']].mean()\
                                  .sort_values(by='MonthlyIncome', ascending=False)\
                                  .reset_index()
cluster_income_pivot
# Out:
#                                         Cluster  MonthlyIncome
# 0                             Senior Executives   18946.187500
# 1                     Specialized professionals   18385.133333
# 2               Experienced senior professional   18293.888889
# 3  Highly experienced late-career professionals   18147.764706
# 4          Experienced Mid-Salary Professionals   12759.315789
# 5                          Veteran Professional   12741.000000
# 6                   Mid-to-senior professionals   10145.243902
# 7                       Mid-career professional    6856.168453
# 8                     Early-career professional    3459.075949

# %%
plt.figure(figsize=(12, 6))

ax = sns.barplot(cluster_income_pivot, y='Cluster', x='MonthlyIncome', errorbar=None)

# Add values next to the bars
ax.bar_label(ax.containers[0])

# Add a vertical line at a specific x-coordinate, e.g., at MonthlyIncome = 5000
plt.axvline(x=analysis_df['MonthlyIncome'].mean(), color='purple', linestyle='--', linewidth=1.5, label='Target Income')

# Label the line
plt.text(analysis_df['MonthlyIncome'].mean() + 100, ax.get_ylim()[0] - 0.1, f'Average Monthly Income: {round(analysis_df['MonthlyIncome'].mean(), 2)}', color='red', 
         ha='left', va='bottom', rotation=0)

plt.title('Average MonthlyIncome per Employee Cluster')
plt.tight_layout()
plt.show()

# %%
analysis_df['MonthlyIncome'].mean()
# Out:
# np.float64(6502.931292517007)

# %% [markdown]
# ### 1.6 **What is the relationship between Monthly Income and Total Working years and Job level**

# %%
plt.figure(figsize=(12, 6))

ax = sns.scatterplot(
    data=analysis_df[analysis_df['Attrition'] == 'Yes'],
    x='TotalWorkingYears',
    y='MonthlyIncome',
    size='JobLevel',
    sizes=(50, 500),
    alpha=0.8,
    hue='Cluster',
)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.7 **What is the relationship between MonthlyIncome and YearsAtCompany along with Job level.**

# %%
plt.figure(figsize=(12, 6))

ax = sns.scatterplot(
    data=analysis_df[analysis_df['Attrition'] == 'Yes'],
    x='YearsAtCompany',
    y='MonthlyIncome',
    size='JobLevel',
    sizes=(50, 500),
    alpha=0.8,
    hue='Cluster',
)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.8 **Which cluster works the most overtime?**

# %%
analysis_df.head()
# Out:
#    Age       AgeBin Attrition     BusinessTravel              Department  \
# 0   41   Middle Age       Yes      Travel_Rarely                   Sales
# 1   49   Middle Age        No  Travel_Frequently  Research & Development
# 2   37  Young Adult       Yes      Travel_Rarely  Research & Development
# 3   33  Young Adult        No  Travel_Frequently  Research & Development
# 4   27  Young Adult        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
# Use crosstab to create the pivoted DataFrame with "Yes" and "No" columns for OverTime
analysis_df_pivot = pd.crosstab(index=analysis_df['Cluster'], columns=analysis_df['OverTime'])

# Rename columns for clarity
analysis_df_pivot = analysis_df_pivot.rename(columns={'Yes': 'Total Yes', 'No': 'Total No'})

# Display the resulting DataFrame
print(analysis_df_pivot)
# Out:
# OverTime                                      Total No  Total Yes
# Cluster
# Early-career professional                          450        182
# Experienced Mid-Salary Professionals                15          4
# Experienced senior professional                     28          8
# Highly experienced late-career professionals        12          5
# Mid-career professional                            471        182
# Mid-to-senior professionals                         28         13
# Senior Executives                                   10          6
# Specialized professionals                           34         11
# Veteran Professional                                 6          5

# %%
# Reset the index to prepare for melting
analysis_df_pivot = analysis_df_pivot.reset_index()

# Melt the DataFrame for long-form data compatible with Seaborn
analysis_df_long = analysis_df_pivot.melt(id_vars='Cluster', 
                                          value_vars=['Total Yes', 'Total No'], 
                                          var_name='OverTime', 
                                          value_name='Count')

# Map 'Total Yes' and 'Total No' back to 'Yes' and 'No' for clarity
analysis_df_long['OverTime'] = analysis_df_long['OverTime'].map({'Total Yes': 'Yes', 'Total No': 'No'})

# Sort the DataFrame by 'Count' in ascending order
analysis_df_long['Cluster'] = pd.Categorical(analysis_df_long['Cluster'], 
                                              categories=analysis_df_long.groupby('Cluster')['Count'].sum().sort_values().index, 
                                              ordered=True)

# Plot using seaborn
plt.figure(figsize=(10, 6))
barplot = sns.barplot(data=analysis_df_long, y='Cluster', x='Count', hue='OverTime')

# Add annotations on the bars
for p in barplot.patches:
    barplot.annotate(format(p.get_width(), '.0f'), 
                      (p.get_width(), p.get_y() + p.get_height() / 2), 
                      ha='left', va='center')


# Add labels and title
plt.xlabel('Count')
plt.ylabel('Cluster')
plt.title('Count of Overtime by Cluster')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.legend(title='OverTime')

plt.show()

# %%
cluster_workBalance_pivot = pd.crosstab(index=analysis_df['Cluster'], columns=analysis_df['WorkLifeBalance']).reset_index()
cluster_workBalance_pivot
# Out:
# WorkLifeBalance                                       Cluster   1    2    3  \
# 0                                   Early-career professional  39  146  388
# 1                        Experienced Mid-Salary Professionals   2    7    9
# 2                             Experienced senior professional   1    8   24
# 3                Highly experienced late-career professionals   0    5   11
# 4                                     Mid-career professional  33  150  395
# 5                                 Mid-to-senior professionals   3    8   25
# 6                                           Senior Executives   1    3   10
# 7                                   Specialized professionals   1   13   24
# 8                                        Veteran Professional   0    4    7
#
# WorkLifeBalance   4
# 0                59
# 1                 1
# 2                 3
# 3                 1
# 4                75
# 5                 5
# 6                 2
# 7                 7
# ...

# %%
melt_df = cluster_workBalance_pivot.melt(id_vars='Cluster',
          value_vars=[1, 2, 3, 4],
          var_name='WorkLifeBalance',
          value_name='Count').sort_values(by='Count', ascending=False)
melt_df
# Out:
#                                          Cluster WorkLifeBalance  Count
# 22                       Mid-career professional               3    395
# 18                     Early-career professional               3    388
# 13                       Mid-career professional               2    150
# 9                      Early-career professional               2    146
# 31                       Mid-career professional               4     75
# 27                     Early-career professional               4     59
# 0                      Early-career professional               1     39
# 4                        Mid-career professional               1     33
# 23                   Mid-to-senior professionals               3     25
# 20               Experienced senior professional               3     24
# 25                     Specialized professionals               3     24
# 16                     Specialized professionals               2     13
# ...

# %%
groupby_melt = melt_df.groupby(by=['Cluster', 'WorkLifeBalance'], as_index=False)[['Count']].sum()

# Calculate the total count for each Cluster
cluster_totals = groupby_melt.groupby('Cluster')['Count'].transform('sum')

# Calculate the percentage for each row
groupby_melt['Percentage'] = round((groupby_melt['Count'] / cluster_totals) * 100, 2)

# Map the WorkLifeBalance values
work_life_balance_map = {
    1: 'Bad',
    2: 'Good',
    3: 'Better',
    4: 'Best'
}
groupby_melt['WorkLifeBalance'] = groupby_melt['WorkLifeBalance'].map(work_life_balance_map).sort_values(ascending=False)
groupby_melt
# Out:
#                                          Cluster WorkLifeBalance  Count  \
# 0                      Early-career professional             Bad     39
# 1                      Early-career professional            Good    146
# 2                      Early-career professional          Better    388
# 3                      Early-career professional            Best     59
# 4           Experienced Mid-Salary Professionals             Bad      2
# 5           Experienced Mid-Salary Professionals            Good      7
# 6           Experienced Mid-Salary Professionals          Better      9
# 7           Experienced Mid-Salary Professionals            Best      1
# 8                Experienced senior professional             Bad      1
# 9                Experienced senior professional            Good      8
# 10               Experienced senior professional          Better     24
# 11               Experienced senior professional            Best      3
# ...

# %%
plt.figure(figsize=(12, 8))

barplot = sns.barplot(groupby_melt, y='Cluster', x='Percentage', hue='WorkLifeBalance', width=1)
barplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Add annotations on the bars
for p in barplot.patches:
    barplot.annotate(format(p.get_width(), '.2f'), 
                      (p.get_width(), p.get_y() + p.get_height() / 2), 
                      ha='left', va='center')

plt.title('Percentage of Worklife Balance Choices per Employee Clustering')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insights (OverTime by Cluster)**:
#
# **Retention rates**
# ___
# * Veteren Professional: For every **1** employee that doesnt work overtime, there is **1** that works overtime.
# * Senior Executive: For every **1** employee that doesnt work overtime, there is **2** that works overtime.
# * Highly experienced late-career professionals: For every **1** employee that doesnt work overtime, there is **2** that works overtime.
# * Experienced Mid-Salaray Professionals: For every **1** employee that doesnt work overtime, there is **4** that works overtime.
# * Experienced Senior Professional: For every **1** employee that doesnt work overtime, there is **4** that works overtime.
# * Mid-to-senior professionals: For every **1** employee that doesnt work overtime, there is **2** that works overtime.
# * Specialized professionals: For every **1** employee that doesnt work overtime, there is **3** that works overtime.
# * Early-career professionals: For every **1** employee that doesnt work overtime, there is **3** that works overtime.
# * Mid-career professionals: For every **1** employee that doesnt work overtime, there is **3** that works overtime.
#
# There seems to be a consistency with regards to the overtime worked by each cluster, added with the fact that across all employee categories, we can see that the average across all employees who would rate their work life balance as bad, only account for **4.5%** of the total staff. Despite overtime being worked at a similar rate across clusters, the impact on attrition varies. This suggests that overtime alone isn't the sole factor; rather, it's how overtime intersects with other conditions, particularly financial compensation.

# %% [markdown]
# ### 1.9 **What is the distribution of Job roles per empoyee clustering?**

# %%
# Create a pivot table with the clusters as the index, and the job levels as the columns
cluster_job_level_pivot = pd.crosstab(index=analysis_df['Cluster'], columns=analysis_df['JobLevel']).reset_index()
cluster_job_level_pivot
# Out:
# JobLevel                                       Cluster    1    2    3   4   5
# 0                            Early-career professional  460  170    2   0   0
# 1                 Experienced Mid-Salary Professionals    0    0    6  13   0
# 2                      Experienced senior professional    0    0    0  15  21
# 3         Highly experienced late-career professionals    0    0    0  10   7
# 4                              Mid-career professional   82  355  193  23   0
# 5                          Mid-to-senior professionals    1    9   14  17   0
# 6                                    Senior Executives    0    0    0   3  13
# 7                            Specialized professionals    0    0    0  17  28
# 8                                 Veteran Professional    0    0    3   8   0

# %%
# Melt the pivot table 
cluster_job_level_melt = cluster_job_level_pivot.melt(id_vars='Cluster',
                          value_vars=[1, 2, 3, 4, 5],
                          var_name='JobLevel',
                          value_name='Count')

# %%
job_level_cluster_groupby_melt = cluster_job_level_melt.groupby(by=['Cluster', 'JobLevel'], as_index=False)[['Count']].sum()

# Calculate the total count for each Cluster
cluster_totals = job_level_cluster_groupby_melt.groupby('Cluster')['Count'].transform('sum')

# Calculate the percentage for each row
job_level_cluster_groupby_melt['Percentage'] = round((job_level_cluster_groupby_melt['Count'] / cluster_totals) * 100, 2)
job_level_cluster_groupby_melt
# Out:
#                                          Cluster JobLevel  Count  Percentage
# 0                      Early-career professional        1    460       72.78
# 1                      Early-career professional        2    170       26.90
# 2                      Early-career professional        3      2        0.32
# 3                      Early-career professional        4      0        0.00
# 4                      Early-career professional        5      0        0.00
# 5           Experienced Mid-Salary Professionals        1      0        0.00
# 6           Experienced Mid-Salary Professionals        2      0        0.00
# 7           Experienced Mid-Salary Professionals        3      6       31.58
# 8           Experienced Mid-Salary Professionals        4     13       68.42
# 9           Experienced Mid-Salary Professionals        5      0        0.00
# 10               Experienced senior professional        1      0        0.00
# ...

# %%
plt.figure(figsize=(12, 8))

barplot = sns.barplot(job_level_cluster_groupby_melt, y='Cluster', x='Percentage', hue='JobLevel', width=1)
barplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Total Employees per Job Level by Employee Category')
plt.tight_layout()
plt.show()

# %%
job_level_attrition_pivot = pd.crosstab(index=analysis_df['JobLevel'], columns=analysis_df['Attrition']).reset_index()
job_level_attrition_pivot
# Out:
# Attrition  JobLevel   No  Yes
# 0                 1  400  143
# 1                 2  482   52
# 2                 3  186   32
# 3                 4  101    5
# 4                 5   64    5

# %%
job_level_attrition_melt = job_level_attrition_pivot.melt(id_vars='JobLevel',
                               value_vars=['Yes', 'No'],
                               var_name='Attrition',
                               value_name='Count')
job_level_attrition_melt
# Out:
#    JobLevel Attrition  Count
# 0         1       Yes    143
# 1         2       Yes     52
# 2         3       Yes     32
# 3         4       Yes      5
# 4         5       Yes      5
# 5         1        No    400
# 6         2        No    482
# 7         3        No    186
# 8         4        No    101
# 9         5        No     64

# %%
plt.figure(figsize=(12, 6))

plot = sns.barplot(job_level_attrition_melt, x='JobLevel', y='Count', hue='Attrition')

# Add annotations
for p in plot.patches:
    plot.annotate(
        # Format count as an integer
        format(p.get_height(), '.0f'),
        # Position text on top of the bar
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center', 
        # Offset text by 5 points vertically
        xytext=(0, 5),  
        textcoords='offset points'
    )

plt.title('Total Attrition per Job Level')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

ax = sns.barplot(analysis_df, y='MonthlyIncome', x='JobLevel', estimator='mean', errorbar=None)
# Add annotations
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')

plt.title('Average Monthly Income oer Job Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insights (Attrition by JobLevel)**:
#
# **Job Level**
# ___
# * *Level 1*: There are a total of **543** employees who's job level is level 1. The retention rate in this job level is **3** employees  being retained for ever **1** that leaves the organisation.
# * *Level 2*: There are a total of **534** employees who's job level is level 2. The retention rate in this job level is **9** employees  being retained for ever **1** that leaves the organisation.
# * *Level 3*: There are a total of **218** employees who's job level is level 3. The retention rate in this job level is **6** employees  being retained for ever **1** that leaves the organisation.
# * *Level 4*: There are a total of **106** employees who's job level is level 4. The retention rate in this job level is **20** employees  being retained for ever **1** that leaves the organisation.
# * *Level 5*: There are a total of **69** employees who's job level is level 5. The retention rate in this job level is **13** employees  being retained for ever **1** that leaves the organisation.
#
# **Job Level per Cluster**
# ___
# * We can see that most of the lower level jobs are occupied by Early-career and Mid-career professionals.
#
# **Job Level average monthly income**
# ___
# * We can also see that there is a direct correlation to the job level and monthly income earned by employees in that job level.
#
# The bar plot above suggests that within JobLevel 1, there is a lower retention rate, than any other job level.
